# %%
#kütüphaneleri içe aktarıyoruz
from ultralytics import YOLO

# %%
#hangi modeli kullanacağımızı belirliyoruz.
model = YOLO("yolo11n.pt")

# %%
sonuc = model(source= "insan.webp",save=True)
#sonuc ile tahminleme sonuçlarını alıyoruz ve gösteriyoruz

sonuc[0].show()
# Out:
# image 1/1 c:\Users\furka\OneDrive\Masast\meetup\insan.webp: 384x640 5 persons, 2 ties, 4 chairs, 124.9ms
# Speed: 7.9ms preprocess, 124.9ms inference, 15.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to C:\Users\furka\OneDrive\Masast\meetup\runs\detect\predict
